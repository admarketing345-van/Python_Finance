# %%
import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt

# %%
start_date = '2020-01-01'
end_date = '2025-10-01'
# Download data 
ticker = 'SPY'
df = yf.download(ticker, start_date, end_date)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_1168\811619917.py:5: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start_date, end_date)
# [*********************100%***********************]  1 of 1 completed

# %%
df.columns = df.columns.droplevel(1)

# %%
df['return'] = df['Close'].pct_change()
df['cum return'] = (1 + df['return']).cumprod() - 1

# %%
df = df.dropna()
df.head(5)
# Out:
# Price            Close        High         Low        Open    Volume  \
# Date
# 2020-01-03  296.317749  297.448217  295.113768  295.168910  77709700
# 2020-01-06  297.448242  297.530955  294.433661  294.553145  55653900
# 2020-01-07  296.611908  297.356354  296.161544  296.878418  40496400
# 2020-01-08  298.192719  299.415071  296.556773  296.804912  68296000
# 2020-01-09  300.214539  300.288080  299.175984  299.764203  48473300
#
# Price         return  cum return
# Date
# 2020-01-03 -0.007572   -0.007572
# 2020-01-06  0.003815   -0.003786
# 2020-01-07 -0.002812   -0.006587
# 2020-01-08  0.005330   -0.001293
# 2020-01-09  0.006780    0.005479

# %%
#vissualize the return
plt.figure(figsize=(10,6))
plt.plot(df['cum return'])
plt.title(f'{ticker} return')
plt.xlabel('Date')
plt.ylabel('return')
plt.grid(True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
